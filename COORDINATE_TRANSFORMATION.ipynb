# %%
import numpy as np
import math
import matplotlib.pyplot as plt
# %matplotlib inline


r = np.arange(0, 2, 0.01)
theta = 2 * np.pi * r

ax = plt.subplot(111, projection='polar')
ax.plot(theta, r)
ax.set_rmax(2)
ax.set_rticks([0.5, 1, 1.5, 2])  # less radial ticks
ax.set_rlabel_position(-22.5)  # get radial labels away from plotted line
ax.grid(True)

ax.set_title("A line plot on a polar axis", va='bottom')
plt.show()

# %%
plt.plot(r, theta)

# %%
x1 = [-1.659210,1.778085,-1.157881, 1.750403, 1.632108, 0.374360, -0.985459,-1.257384,1.883186,-0.350791]
y1 = [0.432926,0.141891,-0.745120,-0.325964, 1.048551, -1.788189, 1.572631, 0.907680,-0.058582,-1.142901]
      
      
x2 = [7.439798, 1.705802, 6.218376, 4.99594, 5.992968, -6.371134, -3.50908, -4.069704, 5.55122, -0.372878]
y2 = [-0.86477, 6.332402, -0.608208, -5.91885, 2.116626,  4.829178, 6.733772, 5.916674, -3.54521, 7.521182]
      
x3 = [8.340790, 11.778085,8.842119,11.750403,11.632108,10.374360,9.014541,8.742616,11.883186,9.649209]
y3 = [10.432926,10.141891, 9.254880, 9.674036, 11.048551, 8.211811,11.572631, 10.907680, 9.941418, 8.857099 ]
      
x4 = [3.719899, 0.852901,3.109188,2.497970,2.996484,-3.185567,-1.754540,-2.034852,2.775610,-0.186439]
y4 = [-0.432385, 3.166201, -0.304104, -2.959425, 1.058313, 2.414589, 3.366886, 2.958337, -1.772605,3.760591 ]
      
plt.scatter(x1,y1, color = 'red', alpha = 0.25, s = 100)
plt.scatter(x2,y2, color = 'blue', alpha = 0.25, s = 100)
plt.scatter(x3,y3, color = 'green', alpha = 0.25, s = 100)
plt.scatter(x4,y4, color = 'm', alpha = 0.25, s = 100)

# %%
print(list(zip(x1,y1)))
print(list(zip(x2,y2)))
print(list(zip(x3,y3)))
print(list(zip(x4,y4)))
# Out:
# [(-1.65921, 0.432926), (1.778085, 0.141891), (-1.157881, -0.74512), (1.750403, -0.325964), (1.632108, 1.048551), (0.37436, -1.788189), (-0.985459, 1.572631), (-1.257384, 0.90768), (1.883186, -0.058582), (-0.350791, -1.142901)]
# [(7.439798, -0.86477), (1.705802, 6.332402), (6.218376, -0.608208), (4.99594, -5.91885), (5.992968, 2.116626), (-6.371134, 4.829178), (-3.50908, 6.733772), (-4.069704, 5.916674), (5.55122, -3.54521), (-0.372878, 7.521182)]
# [(8.34079, 10.432926), (11.778085, 10.141891), (8.842119, 9.25488), (11.750403, 9.674036), (11.632108, 11.048551), (10.37436, 8.211811), (9.014541, 11.572631), (8.742616, 10.90768), (11.883186, 9.941418), (9.649209, 8.857099)]
# [(3.719899, -0.432385), (0.852901, 3.166201), (3.109188, -0.304104), (2.49797, -2.959425), (2.996484, 1.058313), (-3.185567, 2.414589), (-1.75454, 3.366886), (-2.034852, 2.958337), (2.77561, -1.772605), (-0.186439, 3.760591)]

# %%
plt.figure(num=None, figsize=(8, 6))
plt.plot(x1,y1, color = 'yellow', alpha = 0.45, ls = 'dotted', lw = 0, marker = 'o', ms = 20)
plt.plot(x2,y2, color = 'blue', alpha = 0.45, ls = 'dotted', lw = 0, marker = 'o', ms = 20)
plt.plot(x3,y3, color = 'green', alpha = 0.45, ls = 'dotted', lw = 0, marker = 'o', ms = 20)
plt.plot(x4,y4, color = 'm', alpha = 0.45, ls = 'dotted', lw = 0, marker = 'o', ms = 20)
plt.xlabel('x (How far along)', fontsize = 20)
plt.ylabel('y (How far up)', fontsize = 20)
# Out:
# Text(0,0.5,'y (How far up)')

# %%
r1 = np.sqrt(np.array(x1)**2+np.array(y1)**2)
t1 = np.arctan2(y1,x1)

r2 = np.sqrt(np.array(x2)**2+np.array(y2)**2)
t2 = np.arctan2(y1,x1)

r3 = np.sqrt(np.array(x3)**2+np.array(y3)**2)
t3 = np.arctan2(y3,x3)

r4 = np.sqrt(np.array(x4)**2+np.array(y4)**2)
t4 = np.arctan2(y4,x4)

# %%
plt.figure(num=None, figsize=(8, 6))
plt.scatter(r1,t1, color = 'yellow', alpha = 0.25, s = 100)
plt.scatter(r2,t2, color = 'blue', alpha = 0.25, s = 100)
plt.scatter(r3,t3, color = 'green', alpha = 0.25, s = 100)
plt.scatter(r4,t4, color = 'm', alpha = 0.25, s = 100)

# %%
plt.figure(num=None, figsize=(8, 6))
plt.plot(r1,t1, color = 'yellow', alpha = 0.45, ls = 'dotted', lw = 0, marker = 'o', ms = 20)
plt.plot(r2,t2, color = 'blue', alpha = 0.45, ls = 'dotted', lw = 0, marker = 'o', ms = 20)
plt.plot(r3,t3, color = 'green', alpha = 0.45, ls = 'dotted', lw = 0, marker = 'o', ms = 20)
plt.plot(r4,t4, color = 'm', alpha = 0.45, ls = 'dotted', lw = 0, marker = 'o', ms = 20)
plt.xlabel('r (How far away)', fontsize = 20)
plt.ylabel('theta (What angle)', fontsize = 20)
# Out:
# Text(0,0.5,'theta (What angle)')

# %%
ax = plt.subplot(111, projection='polar')
ax.plot(x1, y1)
ax.grid(True)

ax.set_title("A line plot on a polar axis", va='bottom')
plt.show()
