# %%
import pandas as pd
import json

with open('lead_data/lead_50.json') as data_file:
   data = json.load(data_file)

print(data)
# Out:
# [{'_id': {'$oid': '5b3c951a23f18b54b1851647'}, 'CanUpdate': 'true', 'CreatedInfo': {'CreatedBy': 'e8c43234-4dd2-11e8-8401-22000aa79843', 'CreatedByName': 'Aakar', 'CreatedOn': '2018-07-03 10:14:16'}, 'EngagementScore': '0', 'FirstLandingPageSubmissionDate': 'None', 'IsLead': '1', 'LastModifiedOn': '2018-07-03 10:14:16', 'LeadConversionDate': '2018-07-03 10:14:16', 'LeadLastModifiedOn': '2018-07-03 10:14:16', 'Location': {'mx_City': 'Bengaluru', 'mx_Country': 'India', 'mx_State': 'Karnataka', 'mx_Zip': '000006'}, 'ModificationDetails': {'ModifiedBy': 'e8c43234-4dd2-11e8-8401-22000aa79843', 'ModifiedByName': 'Aakar', 'ModifiedOn': '2018-07-03 10:14:16', 'NotableEvent': 'Created', 'NotableEventdate': '2018-07-03 10:14:16'}, 'OwnerDetails': {'OwnerId': 'e8c43234-4dd2-11e8-8401-22000aa79843', 'OwnerIdEmailAddress': 'aakar@acadgild.com', 'OwnerIdName': 'Aakar'}, 'ProductDetail': {'mx_BU': 'Acadgild', 'mx_Category': 'noncert', 'mx_Channel': 'B2C', 'mx_Product': 'GraphicDesign_IN_Online_NonC
# ...

# %%
lead_df = pd.DataFrame(data)
print(lead_df.head())
# Out:
#   CanUpdate                                        CreatedInfo  \
# 0      true  {'CreatedBy': 'e8c43234-4dd2-11e8-8401-22000aa...
# 1      true  {'CreatedBy': 'ff9ce191-6e3a-11e8-8401-22000aa...
# 2      true  {'CreatedBy': '61261cc9-1f07-11e8-8758-0a106ee...
# 3      true  {'CreatedBy': 'e8c43234-4dd2-11e8-8401-22000aa...
# 4      true  {'CreatedBy': '61261cc9-1f07-11e8-8758-0a106ee...
#
#   EngagementScore FirstLandingPageSubmissionDate IsLead       LastModifiedOn  \
# 0               0                           None      1  2018-07-03 10:14:16
# 1               0                           None      1  2018-07-04 09:36:41
# 2               0                           None      1  2018-07-04 09:39:20
# 3               0                           None      1  2018-07-04 09:42:30
# 4               0                           None      1  2018-07-04 09:47:19
#
#     LeadConversionDate   LeadLastModifiedOn  \
# 0  2018-07-03 10:14:16  2018-07-03 10:14:16
# ...

# %%
print(lead_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 26 columns):
# CanUpdate                         50 non-null object
# CreatedInfo                       50 non-null object
# EngagementScore                   50 non-null object
# FirstLandingPageSubmissionDate    50 non-null object
# IsLead                            50 non-null object
# LastModifiedOn                    50 non-null object
# LeadConversionDate                50 non-null object
# LeadLastModifiedOn                50 non-null object
# Location                          50 non-null object
# ModificationDetails               50 non-null object
# OwnerDetails                      50 non-null object
# ProductDetail                     50 non-null object
# ProspectActivityDate_Max          50 non-null object
# ProspectActivityName_Max          50 non-null object
# ProspectAutoId                    50 non-null object
# ProspectDetails                   50 non-null object
# ...

# %%
print(lead_df['ProspectStage'].unique())
# Out:
# ['Fresh Lead']

# %%
print(lead_df['Score'].unique())
# Out:
# ['0' '1']

# %%
print(lead_df['EngagementScore'].unique())
# Out:
# ['0']

# %%
print(lead_df['QualityScore01'].unique())
# Out:
# ['None']

# %%
print(lead_df['StatusCode'].unique())
# Out:
# ['0']
